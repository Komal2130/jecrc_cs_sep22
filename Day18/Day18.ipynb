# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#df1 = pd.read_csv('r'Day18/df1', index_col=0)
df1 = pd.read_csv('df1', index_col=0)
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# # Graph Functions
# 1. plot                             -Simple Line Plot
# 2. plot.area                        -Filled Version of Line Plot
# 3. plot.bar   /  plot.barh          -Bar Graph
# 4. plot.box                         -Box Plot
# 5. plot.density                     -Density Line (Smooth Curved)
# 6. plot.hexbin                      -Hexagon Version of Scatter with Density
# 7. plot.hist                        -Histogram
# 8. plot.kde                         -Kernel DEnsity Estimator (Density Graph)
# 9. plot.pie                         -Pie Chart of Categorical Data
# 10. plot.scatter                    -Scatter Graph

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df3.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df3.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.hexbin(x='a',y='b', C='c', gridsize=6)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2.plot(); plt.title('Line Plot'); plt.show()
df2.plot.area(); plt.title('Area Plot'); plt.show()
df2.plot.bar(); plt.title('Bar Plot'); plt.show()
df2.plot.box(); plt.title('Box Plot'); plt.show()
df2.plot.barh(); plt.title('Bar Horizontal Plot'); plt.show()
df2.plot.density(); plt.title('Density Plot'); plt.show()
df2.plot.kde(); plt.title('KDE Plot'); plt.show()
df2.plot.hist(); plt.title('Histogram Plot'); plt.show()

df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot'); plt.show()

df2.plot.hexbin(x='a', y='b', C='c', gridsize=6); plt.title(' Hexbin Plot'); plt.show()

# %%
fig = plt.figure(figsize=(20,20))
plt.subplot(4,3,1);df2.plot(); plt.title('Line Plot')
plt.subplot(4,3,2);df2.plot.area(); plt.title('Area Plot')
plt.subplot(4,3,3);df2.plot.bar(); plt.title('Bar Plot')
plt.subplot(4,3,4);df2.plot.box(); plt.title('Box Plot')
plt.subplot(4,3,5);df2.plot.barh(); plt.title('Bar Horizontal Plot')
plt.subplot(4,3,6);df2.plot.density(); plt.title('Density Plot')
plt.subplot(4,3,7);df2.plot.kde(); plt.title('KDE Plot')
plt.subplot(4,3,8);df2.plot.hist(); plt.title('Histogram Plot')
df2.plot.density(); plt.title('Density Plot'); plt.show()
plt.subplot(4,3,9);df2.plot.scatter(x='a', y='b'); plt.title('Scatter Plot')

plt.subplot(4,3,10);df2.plot.hexbin(x='a', y='b', C='c', gridsize=6); plt.title('Hexbin Plot')
# Out:
# Text(0.5, 1.0, 'Hexbin Plot')

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df4 = pd.DataFrame({'gift':[40,60,80,20],'name':['rahul','vinita','vijay','vilakshan']})
df4.head()
# Out:
#    gift       name
# 0    40      rahul
# 1    60     vinita
# 2    80      vijay
# 3    20  vilakshan

# %%
plt.figure(figsize=(5,5))
df4['gift'].plot.pie(autopct='%d%%', labels =df4['name'])
# Out:
# <AxesSubplot:ylabel='gift'>

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Categories
# 1. Categorical Plots  (hue can be used | comparison with categorical)
#     a. countplot    (a single parameter)
#     b.barplot      (one categorical parameter, one numerical parameter | also calculates mean by default)
#     c.boxplot
#     d.violinplot
#     e.swarmplot
# 2. Distribution Plots
#     a.distplot
#     b.displot
#     c.jointplot
#     e.pairplot
#     f.kdeplot
#     f.rugplot
#     g.scatterplot
# 3. Matrix Plots
#     a.heatmap
#     b.clusterplot
#     c.pairplot( same as above one)
# 4. Regression Plot
#     a.lmplot
#     b.regplot
# 5. Grid Plots
#     a.PairGrid
#     b.jointGrid
#     c.FacetGrid

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby(['sex','time'])['day'].value_counts().sort_index()
# Out:
# sex     time
# Male    Lunch   Thur    30
#                 Fri      3
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     0
#                 Fri      7
#                 Sat     59
#                 Sun     58
# Female  Lunch   Thur    31
#                 Fri      4
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     1
#                 Fri      5
#                 Sat     28
#                 Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x='day', y='total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(x='day', y='total_bill', data = tips , estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data = tips, hue='time',estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data = tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data = tips, hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data = tips, hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
